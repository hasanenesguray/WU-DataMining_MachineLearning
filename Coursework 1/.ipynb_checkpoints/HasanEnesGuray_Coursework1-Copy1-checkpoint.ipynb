# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB 
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# %% [markdown]
# **Task (1) – Domain Understanding: Classification or Regression**

# %% [markdown]
# **1.a)**

# %%
df = pd.read_csv('Raw_Males_VF_Dataset_Coursework1.csv')
df
# Out:
#      SUBJECT_ID SEX  AGE_years  BMI   HEIGHT_cm  WEIGHT_kg  \
# 0         B0011   M         47    46      187.0     152.24
# 1         B0012   M         52    54      182.0     167.36
# 2         B0013   M         62    28      175.0      82.92
# 3         B0014   M         56    26        1.8      76.45
# 4         B0015   M         48    25        1.7      65.36
# ...         ...  ..        ...   ...        ...        ...
# 2859      B2870   M         69    41      184.0     130.23
# 2860      B2871   M         63    32      189.0     110.83
# 2861      B2872   M         61    35      180.0     110.32
# 2862      B2873   M         75    48      189.0     159.52
# 2863      B2874   M         74    37      180.0     118.06
#
#       WAIST_CIRCUMFERENCE_cm  DIASTOLIC_BLOOD_PRESSURE_mmHg  \
# 0                        154                            133
# 1                        139                            111
# 2                         93                            118
# 3                         85                             91
# 4                         84                             76
# ...                      ...                            ...
# 2859                     125                             94
# 2860                     107                             94
# 2861                     114                             89
# 2862                     127                            116
# 2863                     131                             78
#
#       SYSTOLIC_BLOOD_PRESSURE_mmHg  WALK_DURATION_PER_DAY_MINUTES  \
# 0                            178.0                             52
# 1                            187.0                             50
# 2                            160.0                             58
# 3                            139.0                            151
# 4                             98.0                            257
# ...                            ...                            ...
# 2859                         123.0                             44
# 2860                         108.0                             46
# 2861                         130.0                             41
# 2862                         159.0                             25
# 2863                         155.0                            112
#
#       COMPUTER_USE_TIME_PER_DAY_HOURS  SMOKING_STATUS  DISCONTINUED_NO_  \
# 0                                   7              0.0             XNBH
# 1                                   3              0.0              NaN
# 2                                   6              0.0              NaN
# 3                                   2              0.0              NaN
# 4                                   6              0.0              NaN
# ...                               ...              ...              ...
# 2859                               16              0.0              NaN
# 2860                                6              0.0              NaN
# 2861                                5              0.0              NaN
# 2862                                3              0.0              NaN
# 2863                                8              0.0              NaN
#
#       CIGARETTES_CONSUMED_PER_DAY  Visceral_Fat_Volume_Litres
# 0                             NaN                       -0.76
# 1                             NaN                       -0.59
# 2                             NaN                        0.59
# 3                             NaN                        0.50
# 4                             NaN                        0.39
# ...                           ...                         ...
# 2859                          NaN                       14.82
# 2860                          NaN                       14.91
# 2861                          NaN                       15.19
# 2862                          NaN                       16.05
# 2863                          NaN                       16.06
#
# [2864 rows x 15 columns]

# %%
#Checking the column names
df.columns
# Out:
# Index(['SUBJECT_ID', 'SEX', 'AGE_years', 'BMI ', 'HEIGHT_cm', 'WEIGHT_kg',
#        'WAIST_CIRCUMFERENCE_cm', 'DIASTOLIC_BLOOD_PRESSURE_mmHg',
#        'SYSTOLIC_BLOOD_PRESSURE_mmHg', 'WALK_DURATION_PER_DAY_MINUTES',
#        'COMPUTER_USE_TIME_PER_DAY_HOURS', 'SMOKING_STATUS ',
#        'DISCONTINUED_NO_', 'CIGARETTES_CONSUMED_PER_DAY',
#        'Visceral_Fat_Volume_Litres'],
#       dtype='object')

# %%
#Removing the spaces from the dataset
df.columns = df.columns.str.replace(' ', '')
df.columns
# Out:
# Index(['SUBJECT_ID', 'SEX', 'AGE_years', 'BMI', 'HEIGHT_cm', 'WEIGHT_kg',
#        'WAIST_CIRCUMFERENCE_cm', 'DIASTOLIC_BLOOD_PRESSURE_mmHg',
#        'SYSTOLIC_BLOOD_PRESSURE_mmHg', 'WALK_DURATION_PER_DAY_MINUTES',
#        'COMPUTER_USE_TIME_PER_DAY_HOURS', 'SMOKING_STATUS', 'DISCONTINUED_NO_',
#        'CIGARETTES_CONSUMED_PER_DAY', 'Visceral_Fat_Volume_Litres'],
#       dtype='object')

# %%
#Target column check
df[df["Visceral_Fat_Volume_Litres"]<0].drop(['SEX','AGE_years','BMI','HEIGHT_cm',
                                                                         'WEIGHT_kg','WAIST_CIRCUMFERENCE_cm',
                                                                        'DIASTOLIC_BLOOD_PRESSURE_mmHg',
                                                                        'SYSTOLIC_BLOOD_PRESSURE_mmHg',
                                                                            'WALK_DURATION_PER_DAY_MINUTES',
                                                                            'COMPUTER_USE_TIME_PER_DAY_HOURS',
                                                                            'DISCONTINUED_NO_'
                                                                        ], axis=1)
# Out:
#   SUBJECT_ID  SMOKING_STATUS  CIGARETTES_CONSUMED_PER_DAY  \
# 0      B0011             0.0                          NaN
# 1      B0012             0.0                          NaN
#
#    Visceral_Fat_Volume_Litres
# 0                       -0.76
# 1                       -0.59

# %%
#Dropping the negative ones with null values, as the visceral fat volume cannot be negative
df = df[df["Visceral_Fat_Volume_Litres"]>0]
df[df["Visceral_Fat_Volume_Litres"]<0].drop(['SEX','AGE_years','BMI','HEIGHT_cm',
                                                                         'WEIGHT_kg','WAIST_CIRCUMFERENCE_cm',
                                                                        'DIASTOLIC_BLOOD_PRESSURE_mmHg',
                                                                        'SYSTOLIC_BLOOD_PRESSURE_mmHg',
                                                                            'WALK_DURATION_PER_DAY_MINUTES',
                                                                            'COMPUTER_USE_TIME_PER_DAY_HOURS',
                                                                            'DISCONTINUED_NO_'
                                                                        ], axis=1)
# Out:
# Empty DataFrame
# Columns: [SUBJECT_ID, SMOKING_STATUS, CIGARETTES_CONSUMED_PER_DAY, Visceral_Fat_Volume_Litres]
# Index: []

# %%
#Outlier check in the Visceral_Fat_Volume_Litres column
df = df.reset_index(drop=True)
sns.boxplot(x = df['Visceral_Fat_Volume_Litres'])
plt.title('Box plot before outlier removing')
plt.show()

old_shape = 0
new_shape = 1

print("Old Shape: ", df.shape)

while old_shape != new_shape:
    ''' Detection '''
    # IQR
    Q1 = np.percentile(df['Visceral_Fat_Volume_Litres'], 25, 
                       interpolation = 'midpoint') 

    Q3 = np.percentile(df['Visceral_Fat_Volume_Litres'], 75,
                       interpolation = 'midpoint') 
    IQR = Q3 - Q1 

    old_shape = df.shape
     

    # Upper bound
    df = df[df['Visceral_Fat_Volume_Litres'] < (Q3+1.5*IQR)]
    # Lower bound
    df = df[df['Visceral_Fat_Volume_Litres'] > (Q1-1.5*IQR)]

    new_shape = df.shape

print("New Shape: ", new_shape)

df = df.reset_index(drop=True)
sns.boxplot(x = df['Visceral_Fat_Volume_Litres'])
plt.title('Box plot after outlier removing')
plt.show()
# Out:
# Old Shape:  (2862, 15)
# New Shape:  (2821, 15)
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_15319/891049041.py:15: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(df['Visceral_Fat_Volume_Litres'], 25,
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_15319/891049041.py:18: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(df['Visceral_Fat_Volume_Litres'], 75,

# %%
#Checking the max value for target column
df["Visceral_Fat_Volume_Litres"].max()
# Out:
# 12.09

# %%
#Setting and appliying the formula to classfiy the target column
def conditions(s):
    if (s['Visceral_Fat_Volume_Litres'] == None):
        return None
    elif (s['Visceral_Fat_Volume_Litres'] <= 3):
        return "Low Risk"
    elif (s['Visceral_Fat_Volume_Litres'] <= 6):
        return "Moderate Risk"
    else:
        return "High Risk"
df['Risk_Level'] = df.apply(conditions, axis=1)
df.head(10)
# Out:
#   SUBJECT_ID SEX  AGE_years  BMI  HEIGHT_cm  WEIGHT_kg  \
# 0      B0013   M         62   28      175.0      82.92
# 1      B0014   M         56   26        1.8      76.45
# 2      B0015   M         48   25        1.7      65.36
# 3      B0016   M         70   27      180.0      76.57
# 4      B0017   M         65   21      189.0      63.37
# 5      B0018   M         54   24      192.0      81.79
# 6      B0019   M         49   23      189.0      74.41
# 7      B0020   M         57   26      188.0      84.00
# 8      B0021   M         61   23      180.0      71.71
# 9      B0022   M         52   24      186.0      75.94
#
#    WAIST_CIRCUMFERENCE_cm  DIASTOLIC_BLOOD_PRESSURE_mmHg  \
# 0                      93                            118
# 1                      85                             91
# 2                      84                             76
# 3                      95                             83
# 4                      76                             93
# 5                      87                             81
# 6                      80                             95
# 7                      91                             82
# 8                      85                             78
# 9                      81                            103
#
#    SYSTOLIC_BLOOD_PRESSURE_mmHg  WALK_DURATION_PER_DAY_MINUTES  \
# 0                         160.0                             58
# 1                         139.0                            151
# 2                          98.0                            257
# 3                         127.0                             68
# 4                         123.0                             85
# 5                         123.0                             38
# 6                         136.0                             44
# 7                         109.0                             61
# 8                         112.0                            175
# 9                         138.0                             43
#
#    COMPUTER_USE_TIME_PER_DAY_HOURS  SMOKING_STATUS DISCONTINUED_NO_  \
# 0                                6             0.0              NaN
# 1                                2             0.0              NaN
# 2                                6             0.0              NaN
# 3                                5             0.0              NaN
# 4                                3             0.0              NaN
# 5                               10             0.0              NaN
# 6                                3             0.0              NaN
# 7                                0             0.0              NaN
# 8                                5             0.0              NaN
# 9                                5             0.0             GFTY
#
#    CIGARETTES_CONSUMED_PER_DAY  Visceral_Fat_Volume_Litres Risk_Level
# 0                          NaN                        0.59   Low Risk
# 1                          NaN                        0.50   Low Risk
# 2                          NaN                        0.39   Low Risk
# 3                          NaN                        0.27   Low Risk
# 4                          NaN                        0.24   Low Risk
# 5                          NaN                        0.23   Low Risk
# 6                          NaN                        0.22   Low Risk
# 7                          NaN                        0.18   Low Risk
# 8                          NaN                        0.14   Low Risk
# 9                          NaN                        0.07   Low Risk

# %%
#Checking the classification column of the target column
print("Low Risk Max: ", df[df['Risk_Level'] == "Low Risk"].Visceral_Fat_Volume_Litres.max())
print("Low Risk Min: ", df[df['Risk_Level'] == "Low Risk"].Visceral_Fat_Volume_Litres.min())
print("Moderate Risk Max: ", df[df['Risk_Level'] == "Moderate Risk"].Visceral_Fat_Volume_Litres.max())
print("Moderate Risk Min: ", df[df['Risk_Level'] == "Moderate Risk"].Visceral_Fat_Volume_Litres.min())
print("High Risk Max: ", df[df['Risk_Level'] == "High Risk"].Visceral_Fat_Volume_Litres.max())
print("High Risk Min: ", df[df['Risk_Level'] == "High Risk"].Visceral_Fat_Volume_Litres.min())
# Out:
# Low Risk Max:  2.99
# Low Risk Min:  0.04
# Moderate Risk Max:  6.0
# Moderate Risk Min:  3.01
# High Risk Max:  12.09
# High Risk Min:  6.01

# %%
#Checking the null values and measurement scale types of df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2821 entries, 0 to 2820
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   SUBJECT_ID                       2821 non-null   object
#  1   SEX                              2821 non-null   object
#  2   AGE_years                        2821 non-null   int64
#  3   BMI                              2821 non-null   int64
#  4   HEIGHT_cm                        2821 non-null   float64
#  5   WEIGHT_kg                        2821 non-null   float64
#  6   WAIST_CIRCUMFERENCE_cm           2821 non-null   int64
#  7   DIASTOLIC_BLOOD_PRESSURE_mmHg    2821 non-null   int64
#  8   SYSTOLIC_BLOOD_PRESSURE_mmHg     2817 non-null   float64
#  9   WALK_DURATION_PER_DAY_MINUTES    2821 non-null   int64
#  10  COMPUTER_USE_TIME_PER_DAY_HOURS  2821 non-null   int64
#  11  SMOKING_STATUS                   2819 non-null   float64
#  12  DISCONTINUED_NO_                 1 non-null      object
#  13  CIGARETTES_CONSUMED_PER_DAY      126 non-null    float64
#  14  Visceral_Fat_Volume_Litres       2821 non-null   float64
#  15  Risk_Level                       2821 non-null   object
# dtypes: float64(6), int64(6), object(4)
# memory usage: 352.8+ KB

# %%
#Producing the statistical description of df
df.describe()
# Out:
#          AGE_years          BMI    HEIGHT_cm    WEIGHT_kg  \
# count  2821.000000  2821.000000  2821.000000  2821.000000
# mean     62.327189    29.151365   182.901453    90.858614
# std       8.520792     3.706347     8.701322    13.011089
# min      41.000000    20.000000     1.700000    55.410000
# 25%      57.000000    27.000000   178.000000    81.770000
# 50%      63.000000    29.000000   183.000000    89.520000
# 75%      69.000000    31.000000   188.000000    98.110000
# max     190.000000    51.000000   210.000000   162.940000
#
#        WAIST_CIRCUMFERENCE_cm  DIASTOLIC_BLOOD_PRESSURE_mmHg  \
# count             2821.000000                    2821.000000
# mean                98.736264                      91.545551
# std                  9.771789                      10.592741
# min                 70.000000                      48.000000
# 25%                 92.000000                      84.000000
# 50%                 98.000000                      91.000000
# 75%                104.000000                      98.000000
# max                153.000000                     130.000000
#
#        SYSTOLIC_BLOOD_PRESSURE_mmHg  WALK_DURATION_PER_DAY_MINUTES  \
# count                   2817.000000                    2821.000000
# mean                     133.747959                      81.771358
# std                       16.737795                      64.301588
# min                       90.000000                       1.000000
# 25%                      122.000000                      47.000000
# 50%                      132.000000                      67.000000
# 75%                      144.000000                      92.000000
# max                      192.000000                     656.000000
#
#        COMPUTER_USE_TIME_PER_DAY_HOURS  SMOKING_STATUS  \
# count                      2821.000000     2819.000000
# mean                          4.509039        0.040085
# std                           4.426268        0.196194
# min                           0.000000        0.000000
# 25%                           2.000000        0.000000
# 50%                           3.000000        0.000000
# 75%                           6.000000        0.000000
# max                          69.000000        1.000000
#
#        CIGARETTES_CONSUMED_PER_DAY  Visceral_Fat_Volume_Litres
# count                   126.000000                 2821.000000
# mean                     23.444444                    5.446306
# std                      13.404212                    2.467363
# min                       2.000000                    0.040000
# 25%                      12.000000                    3.660000
# 50%                      21.500000                    5.300000
# 75%                      34.000000                    7.040000
# max                      50.000000                   12.090000

# %%
#Checking the age column
df[df.AGE_years > 100]
# Out:
#      SUBJECT_ID SEX  AGE_years  BMI  HEIGHT_cm  WEIGHT_kg  \
# 1304      B1317   M        190   32      161.0      78.56
#
#       WAIST_CIRCUMFERENCE_cm  DIASTOLIC_BLOOD_PRESSURE_mmHg  \
# 1304                     104                             82
#
#       SYSTOLIC_BLOOD_PRESSURE_mmHg  WALK_DURATION_PER_DAY_MINUTES  \
# 1304                         135.0                             57
#
#       COMPUTER_USE_TIME_PER_DAY_HOURS  SMOKING_STATUS DISCONTINUED_NO_  \
# 1304                                3             0.0              NaN
#
#       CIGARETTES_CONSUMED_PER_DAY  Visceral_Fat_Volume_Litres     Risk_Level
# 1304                          NaN                        5.09  Moderate Risk

# %%
#Replacing the 190 years old with null values, as it is impossible
df['AGE_years'] = df['AGE_years'].replace([190], None)
df = df[df.AGE_years < 100]
df[df.AGE_years > 100]
# Out:
# Empty DataFrame
# Columns: [SUBJECT_ID, SEX, AGE_years, BMI, HEIGHT_cm, WEIGHT_kg, WAIST_CIRCUMFERENCE_cm, DIASTOLIC_BLOOD_PRESSURE_mmHg, SYSTOLIC_BLOOD_PRESSURE_mmHg, WALK_DURATION_PER_DAY_MINUTES, COMPUTER_USE_TIME_PER_DAY_HOURS, SMOKING_STATUS, DISCONTINUED_NO_, CIGARETTES_CONSUMED_PER_DAY, Visceral_Fat_Volume_Litres, Risk_Level]
# Index: []

# %%
#Checking the age column's range
print("Age Max: ", df.AGE_years.max())
print("Age Min: ", df.AGE_years.min())
# Out:
# Age Max:  80
# Age Min:  41

# %%
#Checking the height column
df[df.HEIGHT_cm < 50]
# Out:
#   SUBJECT_ID SEX AGE_years  BMI  HEIGHT_cm  WEIGHT_kg  WAIST_CIRCUMFERENCE_cm  \
# 1      B0014   M        56   26        1.8      76.45                      85
# 2      B0015   M        48   25        1.7      65.36                      84
#
#    DIASTOLIC_BLOOD_PRESSURE_mmHg  SYSTOLIC_BLOOD_PRESSURE_mmHg  \
# 1                             91                         139.0
# 2                             76                          98.0
#
#    WALK_DURATION_PER_DAY_MINUTES  COMPUTER_USE_TIME_PER_DAY_HOURS  \
# 1                            151                                2
# 2                            257                                6
#
#    SMOKING_STATUS DISCONTINUED_NO_  CIGARETTES_CONSUMED_PER_DAY  \
# 1             0.0              NaN                          NaN
# 2             0.0              NaN                          NaN
#
#    Visceral_Fat_Volume_Litres Risk_Level
# 1                        0.50   Low Risk
# 2                        0.39   Low Risk

# %%
#Dropping the misentered height data by prediction
df = df[df.HEIGHT_cm > 50]
df[df.HEIGHT_cm < 50]
# Out:
# Empty DataFrame
# Columns: [SUBJECT_ID, SEX, AGE_years, BMI, HEIGHT_cm, WEIGHT_kg, WAIST_CIRCUMFERENCE_cm, DIASTOLIC_BLOOD_PRESSURE_mmHg, SYSTOLIC_BLOOD_PRESSURE_mmHg, WALK_DURATION_PER_DAY_MINUTES, COMPUTER_USE_TIME_PER_DAY_HOURS, SMOKING_STATUS, DISCONTINUED_NO_, CIGARETTES_CONSUMED_PER_DAY, Visceral_Fat_Volume_Litres, Risk_Level]
# Index: []

# %%
#Checking the statistics
df.describe()
# Out:
#                BMI    HEIGHT_cm    WEIGHT_kg  WAIST_CIRCUMFERENCE_cm  \
# count  2818.000000  2818.000000  2818.000000             2818.000000
# mean     29.152945   183.037793    90.877140               98.744500
# std       3.706631     7.232311    13.004237                9.769114
# min      20.000000   155.000000    55.410000               70.000000
# 25%      27.000000   178.000000    81.802500               92.000000
# 50%      29.000000   183.000000    89.540000               98.000000
# 75%      31.000000   188.000000    98.117500              104.000000
# max      51.000000   210.000000   162.940000              153.000000
#
#        DIASTOLIC_BLOOD_PRESSURE_mmHg  SYSTOLIC_BLOOD_PRESSURE_mmHg  \
# count                    2818.000000                   2814.000000
# mean                       91.554649                    133.758351
# std                        10.592797                     16.732836
# min                        48.000000                     90.000000
# 25%                        84.000000                    122.000000
# 50%                        91.000000                    132.000000
# 75%                        98.000000                    144.000000
# max                       130.000000                    192.000000
#
#        WALK_DURATION_PER_DAY_MINUTES  COMPUTER_USE_TIME_PER_DAY_HOURS  \
# count                    2818.000000                      2818.000000
# mean                       81.693400                         4.509936
# std                        64.236067                         4.428192
# min                         1.000000                         0.000000
# 25%                        47.000000                         2.000000
# 50%                        67.000000                         3.000000
# 75%                        92.000000                         6.000000
# max                       656.000000                        69.000000
#
#        SMOKING_STATUS  CIGARETTES_CONSUMED_PER_DAY  Visceral_Fat_Volume_Litres
# count     2816.000000                   126.000000                 2818.000000
# mean         0.040128                    23.444444                    5.449982
# std          0.196294                    13.404212                    2.465065
# min          0.000000                     2.000000                    0.040000
# 25%          0.000000                    12.000000                    3.660000
# 50%          0.000000                    21.500000                    5.300000
# 75%          0.000000                    34.000000                    7.040000
# max          1.000000                    50.000000                   12.090000

# %%
#Checking the SYSTOLIC_BLOOD_PRESSURE_mmHg variable
df[df['SYSTOLIC_BLOOD_PRESSURE_mmHg'].isnull()].drop(['DIASTOLIC_BLOOD_PRESSURE_mmHg'], axis=1)
# Out:
#      SUBJECT_ID SEX AGE_years  BMI  HEIGHT_cm  WEIGHT_kg  \
# 125       B0138   M        63   26      182.0      82.65
# 1082      B1095   M        62   28      185.0      91.19
# 2289      B2302   M        77   31      181.0      90.32
# 2732      B2745   M        57   29      181.0      89.24
#
#       WAIST_CIRCUMFERENCE_cm  SYSTOLIC_BLOOD_PRESSURE_mmHg  \
# 125                       95                           NaN
# 1082                      97                           NaN
# 2289                      98                           NaN
# 2732                      98                           NaN
#
#       WALK_DURATION_PER_DAY_MINUTES  COMPUTER_USE_TIME_PER_DAY_HOURS  \
# 125                              65                                0
# 1082                             77                                4
# 2289                             31                                9
# 2732                             97                                0
#
#       SMOKING_STATUS DISCONTINUED_NO_  CIGARETTES_CONSUMED_PER_DAY  \
# 125              0.0              NaN                          NaN
# 1082             0.0              NaN                          NaN
# 2289             0.0              NaN                          NaN
# 2732             0.0              NaN                          NaN
#
#       Visceral_Fat_Volume_Litres     Risk_Level
# 125                         1.34       Low Risk
# 1082                        4.57  Moderate Risk
# 2289                        7.66      High Risk
# 2732                       10.36      High Risk

# %%
#Checking the distribution
sns.displot(df, x="SYSTOLIC_BLOOD_PRESSURE_mmHg")

# %%
#Filling the missing records with the mean for systolic blood pressure variable
df['SYSTOLIC_BLOOD_PRESSURE_mmHg'] = df['SYSTOLIC_BLOOD_PRESSURE_mmHg'].fillna(df['SYSTOLIC_BLOOD_PRESSURE_mmHg'].mean())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2818 entries, 0 to 2820
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   SUBJECT_ID                       2818 non-null   object
#  1   SEX                              2818 non-null   object
#  2   AGE_years                        2818 non-null   object
#  3   BMI                              2818 non-null   int64
#  4   HEIGHT_cm                        2818 non-null   float64
#  5   WEIGHT_kg                        2818 non-null   float64
#  6   WAIST_CIRCUMFERENCE_cm           2818 non-null   int64
#  7   DIASTOLIC_BLOOD_PRESSURE_mmHg    2818 non-null   int64
#  8   SYSTOLIC_BLOOD_PRESSURE_mmHg     2818 non-null   float64
#  9   WALK_DURATION_PER_DAY_MINUTES    2818 non-null   int64
#  10  COMPUTER_USE_TIME_PER_DAY_HOURS  2818 non-null   int64
#  11  SMOKING_STATUS                   2816 non-null   float64
#  12  DISCONTINUED_NO_                 1 non-null      object
#  13  CIGARETTES_CONSUMED_PER_DAY      126 non-null    float64
#  14  Visceral_Fat_Volume_Litres       2818 non-null   float64
#  15  Risk_Level                       2818 non-null   object
# dtypes: float64(6), int64(5), object(5)
# memory usage: 438.8+ KB

# %%
#Checking the SYSTOLIC_BLOOD_PRESSURE_mmHg variable
df[df['SUBJECT_ID'].isin(['B0138','B1095','B2302','B2745','B2844'])].drop(['DIASTOLIC_BLOOD_PRESSURE_mmHg'], axis=1)
# Out:
#      SUBJECT_ID SEX AGE_years  BMI  HEIGHT_cm  WEIGHT_kg  \
# 125       B0138   M        63   26      182.0      82.65
# 1082      B1095   M        62   28      185.0      91.19
# 2289      B2302   M        77   31      181.0      90.32
# 2732      B2745   M        57   29      181.0      89.24
#
#       WAIST_CIRCUMFERENCE_cm  SYSTOLIC_BLOOD_PRESSURE_mmHg  \
# 125                       95                    133.758351
# 1082                      97                    133.758351
# 2289                      98                    133.758351
# 2732                      98                    133.758351
#
#       WALK_DURATION_PER_DAY_MINUTES  COMPUTER_USE_TIME_PER_DAY_HOURS  \
# 125                              65                                0
# 1082                             77                                4
# 2289                             31                                9
# 2732                             97                                0
#
#       SMOKING_STATUS DISCONTINUED_NO_  CIGARETTES_CONSUMED_PER_DAY  \
# 125              0.0              NaN                          NaN
# 1082             0.0              NaN                          NaN
# 2289             0.0              NaN                          NaN
# 2732             0.0              NaN                          NaN
#
#       Visceral_Fat_Volume_Litres     Risk_Level
# 125                         1.34       Low Risk
# 1082                        4.57  Moderate Risk
# 2289                        7.66      High Risk
# 2732                       10.36      High Risk

# %%
#Checking the computer use time column
df[df.COMPUTER_USE_TIME_PER_DAY_HOURS > 24].drop(['SEX','AGE_years','BMI','HEIGHT_cm',
                                                                         'WEIGHT_kg','WAIST_CIRCUMFERENCE_cm',
                                                                        'DIASTOLIC_BLOOD_PRESSURE_mmHg',
                                                                        'SYSTOLIC_BLOOD_PRESSURE_mmHg',
                                                                        ], axis=1)
# Out:
#      SUBJECT_ID  WALK_DURATION_PER_DAY_MINUTES  \
# 315       B0328                             65
# 324       B0337                             67
# 713       B0726                             48
# 1124      B1137                             61
# 1178      B1191                            102
# 1247      B1260                             86
# 1336      B1349                             91
# 1585      B1598                             68
# 2324      B2337                             80
# 2604      B2617                             11
# 2618      B2631                             42
# 2806      B2819                             74
#
#       COMPUTER_USE_TIME_PER_DAY_HOURS  SMOKING_STATUS DISCONTINUED_NO_  \
# 315                                30             0.0              NaN
# 324                                32             0.0              NaN
# 713                                27             0.0              NaN
# 1124                               30             0.0              NaN
# 1178                               69             0.0              NaN
# 1247                               35             0.0              NaN
# 1336                               25             0.0              NaN
# 1585                               46             0.0              NaN
# 2324                               32             0.0              NaN
# 2604                               25             0.0              NaN
# 2618                               26             0.0              NaN
# 2806                               28             0.0              NaN
#
#       CIGARETTES_CONSUMED_PER_DAY  Visceral_Fat_Volume_Litres     Risk_Level
# 315                           NaN                        2.50       Low Risk
# 324                           NaN                        2.53       Low Risk
# 713                           NaN                        3.68  Moderate Risk
# 1124                         11.0                        4.69  Moderate Risk
# 1178                          NaN                        4.81  Moderate Risk
# 1247                          NaN                        4.98  Moderate Risk
# 1336                          NaN                        5.15  Moderate Risk
# 1585                          NaN                        5.76  Moderate Risk
# 2324                          NaN                        7.79      High Risk
# 2604                          NaN                        9.18      High Risk
# 2618                          NaN                        9.25      High Risk
# 2806                          NaN                       11.70      High Risk

# %%
#Replacing the computer use time with null
df = df[df.COMPUTER_USE_TIME_PER_DAY_HOURS <= 24]
df[df.COMPUTER_USE_TIME_PER_DAY_HOURS > 24].drop(['SEX','AGE_years','BMI','HEIGHT_cm',
                                                                         'WEIGHT_kg','WAIST_CIRCUMFERENCE_cm',
                                                                        'DIASTOLIC_BLOOD_PRESSURE_mmHg',
                                                                        'SYSTOLIC_BLOOD_PRESSURE_mmHg',
                                                                        ], axis=1)
# Out:
# Empty DataFrame
# Columns: [SUBJECT_ID, WALK_DURATION_PER_DAY_MINUTES, COMPUTER_USE_TIME_PER_DAY_HOURS, SMOKING_STATUS, DISCONTINUED_NO_, CIGARETTES_CONSUMED_PER_DAY, Visceral_Fat_Volume_Litres, Risk_Level]
# Index: []

# %%
df[df.SUBJECT_ID.isin(["B0328","B0337","B0726","B0817","B0892","B1078","B1137","B1191","B1260","B1349","B1598","B2223"
                       ,"B2337","B2617","B2625","B2631","B2819"])].drop(['SEX','AGE_years','BMI','HEIGHT_cm',
                                                                         'WEIGHT_kg','WAIST_CIRCUMFERENCE_cm',
                                                                        'DIASTOLIC_BLOOD_PRESSURE_mmHg',
                                                                        'SYSTOLIC_BLOOD_PRESSURE_mmHg',
                                                                        ], axis=1)
# Out:
#      SUBJECT_ID  WALK_DURATION_PER_DAY_MINUTES  \
# 804       B0817                             80
# 879       B0892                             52
# 1065      B1078                            104
# 2210      B2223                             62
# 2612      B2625                             49
#
#       COMPUTER_USE_TIME_PER_DAY_HOURS  SMOKING_STATUS DISCONTINUED_NO_  \
# 804                                24             0.0              NaN
# 879                                24             0.0              NaN
# 1065                               24             0.0              NaN
# 2210                               24             0.0              NaN
# 2612                               24             0.0              NaN
#
#       CIGARETTES_CONSUMED_PER_DAY  Visceral_Fat_Volume_Litres     Risk_Level
# 804                           NaN                        3.92  Moderate Risk
# 879                           NaN                        4.08  Moderate Risk
# 1065                          NaN                        4.54  Moderate Risk
# 2210                          NaN                        7.37      High Risk
# 2612                          NaN                        9.23      High Risk

# %%
#Sanity check for smoking
df[(df['CIGARETTES_CONSUMED_PER_DAY']>0) & (df['SMOKING_STATUS']!=1)].drop(['SEX','AGE_years','BMI','HEIGHT_cm',
                                                                         'WEIGHT_kg','WAIST_CIRCUMFERENCE_cm',
                                                                        'DIASTOLIC_BLOOD_PRESSURE_mmHg',
                                                                        'SYSTOLIC_BLOOD_PRESSURE_mmHg',
                                                                            'WALK_DURATION_PER_DAY_MINUTES',
                                                                            'COMPUTER_USE_TIME_PER_DAY_HOURS',
                                                                            'DISCONTINUED_NO_'
                                                                        ], axis=1)
# Out:
#      SUBJECT_ID  SMOKING_STATUS  CIGARETTES_CONSUMED_PER_DAY  \
# 245       B0258             NaN                          8.0
# 439       B0452             NaN                          2.0
# 474       B0487             0.0                         17.0
# 541       B0554             0.0                          9.0
# 714       B0727             0.0                         13.0
# 1169      B1182             0.0                         12.0
# 1176      B1189             0.0                          8.0
# 1183      B1196             0.0                         45.0
# 1509      B1522             0.0                         13.0
# 1799      B1812             0.0                          5.0
# 2362      B2375             0.0                         28.0
# 2540      B2553             0.0                         12.0
#
#       Visceral_Fat_Volume_Litres     Risk_Level
# 245                         2.18       Low Risk
# 439                         2.93       Low Risk
# 474                         3.04  Moderate Risk
# 541                         3.26  Moderate Risk
# 714                         3.68  Moderate Risk
# 1169                        4.79  Moderate Risk
# 1176                        4.81  Moderate Risk
# 1183                        4.82  Moderate Risk
# 1509                        5.56  Moderate Risk
# 1799                        6.26      High Risk
# 2362                        8.01      High Risk
# 2540                        8.81      High Risk

# %%
df[(df['CIGARETTES_CONSUMED_PER_DAY']!=0) & (df['CIGARETTES_CONSUMED_PER_DAY']!=1)].drop(['SEX','AGE_years','BMI',
                                                                                          'HEIGHT_cm',
                                                                         'WEIGHT_kg','WAIST_CIRCUMFERENCE_cm',
                                                                        'DIASTOLIC_BLOOD_PRESSURE_mmHg',
                                                                        'SYSTOLIC_BLOOD_PRESSURE_mmHg',
                                                                            'WALK_DURATION_PER_DAY_MINUTES',
                                                                            'COMPUTER_USE_TIME_PER_DAY_HOURS',
                                                                            'DISCONTINUED_NO_'
                                                                        ], axis=1)
# Out:
#      SUBJECT_ID  SMOKING_STATUS  CIGARETTES_CONSUMED_PER_DAY  \
# 0         B0013             0.0                          NaN
# 3         B0016             0.0                          NaN
# 4         B0017             0.0                          NaN
# 5         B0018             0.0                          NaN
# 6         B0019             0.0                          NaN
# ...         ...             ...                          ...
# 2816      B2829             0.0                          NaN
# 2817      B2830             0.0                          NaN
# 2818      B2831             0.0                          NaN
# 2819      B2832             0.0                          NaN
# 2820      B2833             0.0                          NaN
#
#       Visceral_Fat_Volume_Litres Risk_Level
# 0                           0.59   Low Risk
# 3                           0.27   Low Risk
# 4                           0.24   Low Risk
# 5                           0.23   Low Risk
# 6                           0.22   Low Risk
# ...                          ...        ...
# 2816                       11.90  High Risk
# 2817                       11.92  High Risk
# 2818                       11.99  High Risk
# 2819                       12.00  High Risk
# 2820                       12.09  High Risk
#
# [2806 rows x 5 columns]

# %%
#Setting and appliying the formula to fill the smoking status with 1 for cigarettes consumers
def smoker_conditions(s):
    if (s['CIGARETTES_CONSUMED_PER_DAY'] > 0):
        return 1
    else:
        return s['SMOKING_STATUS']
df['SMOKING_STATUS'] = df.apply(smoker_conditions, axis=1)

# %%
#Setting and appliying the formula to fill the smoke consumption with 0 for nonsmokers
def nonsmoker_conditions(s):
    if (s['SMOKING_STATUS'] == 0):
        return 0
    else:
        return s['CIGARETTES_CONSUMED_PER_DAY']
df['CIGARETTES_CONSUMED_PER_DAY'] = df.apply(nonsmoker_conditions, axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2806 entries, 0 to 2820
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   SUBJECT_ID                       2806 non-null   object
#  1   SEX                              2806 non-null   object
#  2   AGE_years                        2806 non-null   object
#  3   BMI                              2806 non-null   int64
#  4   HEIGHT_cm                        2806 non-null   float64
#  5   WEIGHT_kg                        2806 non-null   float64
#  6   WAIST_CIRCUMFERENCE_cm           2806 non-null   int64
#  7   DIASTOLIC_BLOOD_PRESSURE_mmHg    2806 non-null   int64
#  8   SYSTOLIC_BLOOD_PRESSURE_mmHg     2806 non-null   float64
#  9   WALK_DURATION_PER_DAY_MINUTES    2806 non-null   int64
#  10  COMPUTER_USE_TIME_PER_DAY_HOURS  2806 non-null   int64
#  11  SMOKING_STATUS                   2806 non-null   float64
#  12  DISCONTINUED_NO_                 1 non-null      object
#  13  CIGARETTES_CONSUMED_PER_DAY      2806 non-null   float64
#  14  Visceral_Fat_Volume_Litres       2806 non-null   float64
#  15  Risk_Level                       2806 non-null   object
# dtypes: float64(6), int64(5), object(5)
# memory usage: 372.7+ KB

# %%
df[df.SUBJECT_ID.isin(['B0258','B0452','B0487','B0554','B0727','B1137','B1182','B1189','B1196','B1522','B1812','B2375','B2553'])].drop(['SEX','AGE_years','BMI','HEIGHT_cm',
                                                                         'WEIGHT_kg','WAIST_CIRCUMFERENCE_cm',
                                                                        'DIASTOLIC_BLOOD_PRESSURE_mmHg',
                                                                        'SYSTOLIC_BLOOD_PRESSURE_mmHg',
                                                                            'WALK_DURATION_PER_DAY_MINUTES',
                                                                            'COMPUTER_USE_TIME_PER_DAY_HOURS',
                                                                            'DISCONTINUED_NO_'
                                                                        ], axis=1)
# Out:
#      SUBJECT_ID  SMOKING_STATUS  CIGARETTES_CONSUMED_PER_DAY  \
# 245       B0258             1.0                          8.0
# 439       B0452             1.0                          2.0
# 474       B0487             1.0                         17.0
# 541       B0554             1.0                          9.0
# 714       B0727             1.0                         13.0
# 1169      B1182             1.0                         12.0
# 1176      B1189             1.0                          8.0
# 1183      B1196             1.0                         45.0
# 1509      B1522             1.0                         13.0
# 1799      B1812             1.0                          5.0
# 2362      B2375             1.0                         28.0
# 2540      B2553             1.0                         12.0
#
#       Visceral_Fat_Volume_Litres     Risk_Level
# 245                         2.18       Low Risk
# 439                         2.93       Low Risk
# 474                         3.04  Moderate Risk
# 541                         3.26  Moderate Risk
# 714                         3.68  Moderate Risk
# 1169                        4.79  Moderate Risk
# 1176                        4.81  Moderate Risk
# 1183                        4.82  Moderate Risk
# 1509                        5.56  Moderate Risk
# 1799                        6.26      High Risk
# 2362                        8.01      High Risk
# 2540                        8.81      High Risk

# %%
df.drop(['SEX','AGE_years','BMI','HEIGHT_cm','WEIGHT_kg','WAIST_CIRCUMFERENCE_cm',
                                                                        'DIASTOLIC_BLOOD_PRESSURE_mmHg',
                                                                        'SYSTOLIC_BLOOD_PRESSURE_mmHg',
                                                                            'WALK_DURATION_PER_DAY_MINUTES',
                                                                            'COMPUTER_USE_TIME_PER_DAY_HOURS',
                                                                            'DISCONTINUED_NO_'
                                                                        ], axis=1)
# Out:
#      SUBJECT_ID  SMOKING_STATUS  CIGARETTES_CONSUMED_PER_DAY  \
# 0         B0013             0.0                          0.0
# 3         B0016             0.0                          0.0
# 4         B0017             0.0                          0.0
# 5         B0018             0.0                          0.0
# 6         B0019             0.0                          0.0
# ...         ...             ...                          ...
# 2816      B2829             0.0                          0.0
# 2817      B2830             0.0                          0.0
# 2818      B2831             0.0                          0.0
# 2819      B2832             0.0                          0.0
# 2820      B2833             0.0                          0.0
#
#       Visceral_Fat_Volume_Litres Risk_Level
# 0                           0.59   Low Risk
# 3                           0.27   Low Risk
# 4                           0.24   Low Risk
# 5                           0.23   Low Risk
# 6                           0.22   Low Risk
# ...                          ...        ...
# 2816                       11.90  High Risk
# 2817                       11.92  High Risk
# 2818                       11.99  High Risk
# 2819                       12.00  High Risk
# 2820                       12.09  High Risk
#
# [2806 rows x 5 columns]

# %%
#Checking the null values a
df[(df['SMOKING_STATUS']!=1) & (df['SMOKING_STATUS']!=0)]
# Out:
# Empty DataFrame
# Columns: [SUBJECT_ID, SEX, AGE_years, BMI, HEIGHT_cm, WEIGHT_kg, WAIST_CIRCUMFERENCE_cm, DIASTOLIC_BLOOD_PRESSURE_mmHg, SYSTOLIC_BLOOD_PRESSURE_mmHg, WALK_DURATION_PER_DAY_MINUTES, COMPUTER_USE_TIME_PER_DAY_HOURS, SMOKING_STATUS, DISCONTINUED_NO_, CIGARETTES_CONSUMED_PER_DAY, Visceral_Fat_Volume_Litres, Risk_Level]
# Index: []

# %%
#Sanity check for smoking
df[(df['SMOKING_STATUS']==0) & (df['CIGARETTES_CONSUMED_PER_DAY']>0)]
# Out:
# Empty DataFrame
# Columns: [SUBJECT_ID, SEX, AGE_years, BMI, HEIGHT_cm, WEIGHT_kg, WAIST_CIRCUMFERENCE_cm, DIASTOLIC_BLOOD_PRESSURE_mmHg, SYSTOLIC_BLOOD_PRESSURE_mmHg, WALK_DURATION_PER_DAY_MINUTES, COMPUTER_USE_TIME_PER_DAY_HOURS, SMOKING_STATUS, DISCONTINUED_NO_, CIGARETTES_CONSUMED_PER_DAY, Visceral_Fat_Volume_Litres, Risk_Level]
# Index: []

# %%
#duplicate check
df = df.drop_duplicates()

# %% [markdown]
# **Task (2) – Data Understanding: Producing Your Experimental Designing**

# %% [markdown]
# **2.a)**

# %%
#Checking the columns
df = df.drop(columns=['DISCONTINUED_NO_','Visceral_Fat_Volume_Litres','SUBJECT_ID','SEX'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2806 entries, 0 to 2820
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   AGE_years                        2806 non-null   object
#  1   BMI                              2806 non-null   int64
#  2   HEIGHT_cm                        2806 non-null   float64
#  3   WEIGHT_kg                        2806 non-null   float64
#  4   WAIST_CIRCUMFERENCE_cm           2806 non-null   int64
#  5   DIASTOLIC_BLOOD_PRESSURE_mmHg    2806 non-null   int64
#  6   SYSTOLIC_BLOOD_PRESSURE_mmHg     2806 non-null   float64
#  7   WALK_DURATION_PER_DAY_MINUTES    2806 non-null   int64
#  8   COMPUTER_USE_TIME_PER_DAY_HOURS  2806 non-null   int64
#  9   SMOKING_STATUS                   2806 non-null   float64
#  10  CIGARETTES_CONSUMED_PER_DAY      2806 non-null   float64
#  11  Risk_Level                       2806 non-null   object
# dtypes: float64(5), int64(5), object(2)
# memory usage: 285.0+ KB

# %%
df.head(10)
# Out:
#    AGE_years  BMI  HEIGHT_cm  WEIGHT_kg  WAIST_CIRCUMFERENCE_cm  \
# 0         62   28      175.0      82.92                      93
# 3         70   27      180.0      76.57                      95
# 4         65   21      189.0      63.37                      76
# 5         54   24      192.0      81.79                      87
# 6         49   23      189.0      74.41                      80
# 7         57   26      188.0      84.00                      91
# 8         61   23      180.0      71.71                      85
# 9         52   24      186.0      75.94                      81
# 10        54   27      177.0      75.32                      91
# 11        53   24      188.0      82.55                      87
#
#     DIASTOLIC_BLOOD_PRESSURE_mmHg  SYSTOLIC_BLOOD_PRESSURE_mmHg  \
# 0                             118                         160.0
# 3                              83                         127.0
# 4                              93                         123.0
# 5                              81                         123.0
# 6                              95                         136.0
# 7                              82                         109.0
# 8                              78                         112.0
# 9                             103                         138.0
# 10                            102                         144.0
# 11                             78                         123.0
#
#     WALK_DURATION_PER_DAY_MINUTES  COMPUTER_USE_TIME_PER_DAY_HOURS  \
# 0                              58                                6
# 3                              68                                5
# 4                              85                                3
# 5                              38                               10
# 6                              44                                3
# 7                              61                                0
# 8                             175                                5
# 9                              43                                5
# 10                             78                                0
# 11                             46                                2
#
#     SMOKING_STATUS  CIGARETTES_CONSUMED_PER_DAY Risk_Level
# 0              0.0                          0.0   Low Risk
# 3              0.0                          0.0   Low Risk
# 4              0.0                          0.0   Low Risk
# 5              0.0                          0.0   Low Risk
# 6              0.0                          0.0   Low Risk
# 7              0.0                          0.0   Low Risk
# 8              0.0                          0.0   Low Risk
# 9              0.0                          0.0   Low Risk
# 10             0.0                          0.0   Low Risk
# 11             0.0                          0.0   Low Risk

# %%
df.describe()
# Out:
#                BMI    HEIGHT_cm    WEIGHT_kg  WAIST_CIRCUMFERENCE_cm  \
# count  2806.000000  2806.000000  2806.000000             2806.000000
# mean     29.154669   183.017463    90.870994               98.743051
# std       3.709355     7.223003    12.994557                9.761208
# min      20.000000   155.000000    55.410000               70.000000
# 25%      27.000000   178.000000    81.830000               92.000000
# 50%      29.000000   183.000000    89.540000               98.000000
# 75%      31.000000   188.000000    98.080000              104.000000
# max      51.000000   210.000000   162.940000              153.000000
#
#        DIASTOLIC_BLOOD_PRESSURE_mmHg  SYSTOLIC_BLOOD_PRESSURE_mmHg  \
# count                    2806.000000                   2806.000000
# mean                       91.568425                    133.799370
# std                        10.582708                     16.687131
# min                        48.000000                     90.000000
# 25%                        84.000000                    122.000000
# 50%                        91.000000                    133.000000
# 75%                        98.000000                    144.000000
# max                       130.000000                    192.000000
#
#        WALK_DURATION_PER_DAY_MINUTES  COMPUTER_USE_TIME_PER_DAY_HOURS  \
# count                    2806.000000                       2806.00000
# mean                       81.759444                          4.38489
# std                        64.347260                          3.92507
# min                         1.000000                          0.00000
# 25%                        47.000000                          2.00000
# 50%                        67.000000                          3.00000
# 75%                        92.000000                          6.00000
# max                       656.000000                         24.00000
#
#        SMOKING_STATUS  CIGARETTES_CONSUMED_PER_DAY
# count     2806.000000                  2806.000000
# mean         0.044547                     1.048824
# std          0.206345                     5.617210
# min          0.000000                     0.000000
# 25%          0.000000                     0.000000
# 50%          0.000000                     0.000000
# 75%          0.000000                     0.000000
# max          1.000000                    50.000000

# %%
#Distribution of the target column's classes
import seaborn as sns
sns.displot(df, x="Risk_Level")

# %%
#Percentages of the target column's classes
df.Risk_Level.value_counts(normalize=True)
# Out:
# Moderate Risk    0.433713
# High Risk        0.403065
# Low Risk         0.163222
# Name: Risk_Level, dtype: float64

# %% [markdown]
# Model

# %%
#check number of rows and columns in dataset
df.shape
# Out:
# (2806, 12)

# %%
#create a dataframe with all training data except the target column
X = df.drop(columns=['Risk_Level'])
#check that the target variable has been removed
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2806 entries, 0 to 2820
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   AGE_years                        2806 non-null   object
#  1   BMI                              2806 non-null   int64
#  2   HEIGHT_cm                        2806 non-null   float64
#  3   WEIGHT_kg                        2806 non-null   float64
#  4   WAIST_CIRCUMFERENCE_cm           2806 non-null   int64
#  5   DIASTOLIC_BLOOD_PRESSURE_mmHg    2806 non-null   int64
#  6   SYSTOLIC_BLOOD_PRESSURE_mmHg     2806 non-null   float64
#  7   WALK_DURATION_PER_DAY_MINUTES    2806 non-null   int64
#  8   COMPUTER_USE_TIME_PER_DAY_HOURS  2806 non-null   int64
#  9   SMOKING_STATUS                   2806 non-null   float64
#  10  CIGARETTES_CONSUMED_PER_DAY      2806 non-null   float64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 327.6+ KB

# %%
#separate target values
y = df['Risk_Level'].values
#view target values
y[0:5]
# Out:
# array(['Low Risk', 'Low Risk', 'Low Risk', 'Low Risk', 'Low Risk'],
#       dtype=object)

# %% [markdown]
# **Task (4) – Modelling: Create Predictive Classification Models**

# %% [markdown]
# **b)**

# %%
from sklearn.model_selection import train_test_split
#split dataset into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# %%
X
# Out:
#      AGE_years  BMI  HEIGHT_cm  WEIGHT_kg  WAIST_CIRCUMFERENCE_cm  \
# 0           62   28      175.0      82.92                      93
# 3           70   27      180.0      76.57                      95
# 4           65   21      189.0      63.37                      76
# 5           54   24      192.0      81.79                      87
# 6           49   23      189.0      74.41                      80
# ...        ...  ...        ...        ...                     ...
# 2816        62   34      204.0     134.16                     118
# 2817        74   36      175.0     101.25                     110
# 2818        73   32      187.0     108.45                     110
# 2819        66   34      176.0     100.17                     104
# 2820        65   44      194.0     157.61                     140
#
#       DIASTOLIC_BLOOD_PRESSURE_mmHg  SYSTOLIC_BLOOD_PRESSURE_mmHg  \
# 0                               118                         160.0
# 3                                83                         127.0
# 4                                93                         123.0
# 5                                81                         123.0
# 6                                95                         136.0
# ...                             ...                           ...
# 2816                             93                         135.0
# 2817                             82                         109.0
# 2818                             89                         113.0
# 2819                             99                         154.0
# 2820                            111                         181.0
#
#       WALK_DURATION_PER_DAY_MINUTES  COMPUTER_USE_TIME_PER_DAY_HOURS  \
# 0                                58                                6
# 3                                68                                5
# 4                                85                                3
# 5                                38                               10
# 6                                44                                3
# ...                             ...                              ...
# 2816                             41                               13
# 2817                             57                               11
# 2818                             63                                7
# 2819                              3                                5
# 2820                             82                                0
#
#       SMOKING_STATUS  CIGARETTES_CONSUMED_PER_DAY
# 0                0.0                          0.0
# 3                0.0                          0.0
# 4                0.0                          0.0
# 5                0.0                          0.0
# 6                0.0                          0.0
# ...              ...                          ...
# 2816             0.0                          0.0
# 2817             0.0                          0.0
# 2818             0.0                          0.0
# 2819             0.0                          0.0
# 2820             0.0                          0.0
#
# [2806 rows x 11 columns]

# %%
minmax_scale = MinMaxScaler()

X_train_scaled = minmax_scale.fit_transform(X_train)
X_test_scaled = minmax_scale.transform(X_test)
X_scaled = minmax_scale.transform(X)
pd.DataFrame(X_scaled)
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.538462  0.258065  0.377358  0.259259  0.277108  0.853659  0.686275
# 1     0.743590  0.225806  0.471698  0.199416  0.301205  0.426829  0.362745
# 2     0.615385  0.032258  0.641509  0.075016  0.072289  0.548780  0.323529
# 3     0.333333  0.129032  0.698113  0.248610  0.204819  0.402439  0.323529
# 4     0.205128  0.096774  0.641509  0.179059  0.120482  0.573171  0.450980
# ...        ...       ...       ...       ...       ...       ...       ...
# 2801  0.538462  0.451613  0.924528  0.742154  0.578313  0.548780  0.441176
# 2802  0.846154  0.516129  0.377358  0.432005  0.481928  0.414634  0.186275
# 2803  0.820513  0.387097  0.603774  0.499859  0.481928  0.500000  0.225490
# 2804  0.641026  0.451613  0.396226  0.421826  0.409639  0.621951  0.627451
# 2805  0.615385  0.774194  0.735849  0.963151  0.843373  0.768293  0.892157
#
#             7         8    9    10
# 0     0.087023  0.250000  0.0  0.0
# 1     0.102290  0.208333  0.0  0.0
# 2     0.128244  0.125000  0.0  0.0
# 3     0.056489  0.416667  0.0  0.0
# 4     0.065649  0.125000  0.0  0.0
# ...        ...       ...  ...  ...
# 2801  0.061069  0.541667  0.0  0.0
# 2802  0.085496  0.458333  0.0  0.0
# 2803  0.094656  0.291667  0.0  0.0
# 2804  0.003053  0.208333  0.0  0.0
# 2805  0.123664  0.000000  0.0  0.0
#
# [2806 rows x 11 columns]

# %%
pd.DataFrame(X_train_scaled).head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.743590  0.225806  0.396226  0.198191  0.397590  0.463415  0.264706
# 1  0.153846  0.419355  0.358491  0.341155  0.301205  0.548780  0.450980
# 2  0.743590  0.387097  0.415094  0.396287  0.421687  0.756098  0.823529
# 3  0.692308  0.225806  0.566038  0.255961  0.228916  0.487805  0.225490
# 4  0.282051  0.193548  0.603774  0.258128  0.180723  0.585366  0.333333
#
#          7         8    9    10
# 0  0.105344  0.333333  0.0  0.0
# 1  0.119084  0.083333  0.0  0.0
# 2  0.170992  0.125000  0.0  0.0
# 3  0.224427  0.000000  0.0  0.0
# 4  0.079389  0.125000  0.0  0.0

# %%
pd.DataFrame(y_train).head()
# Out:
#                0
# 0  Moderate Risk
# 1       Low Risk
# 2  Moderate Risk
# 3  Moderate Risk
# 4       Low Risk

# %%
# Create KNN classifier
knn = KNeighborsClassifier()
knn.fit(X_train_scaled,y_train)
knn.score(X_test_scaled, y_test)
# Out:
# 0.5551601423487544

# %%
# Create Multinomial Naive Bayes classifier
mnb = MultinomialNB()
mnb.fit(X_train_scaled, y_train)
mnb.score(X_test_scaled, y_test)
# Out:
# 0.5427046263345195

# %%
# Create Gaussian Naive Bayes classifier
gnb = GaussianNB()
gnb.fit(X_train_scaled, y_train)
gnb.score(X_test_scaled, y_test)
# Out:
# 0.5765124555160143

# %%
# Create Bernoulli Naive Bayes classifier
bnb = BernoulliNB()
bnb.fit(X_train_scaled, y_train)
bnb.score(X_test_scaled, y_test)
# Out:
# 0.42526690391459077

# %%
# Create Decision Tree classifier
dtc = DecisionTreeClassifier()
dtc = dtc.fit(X_train_scaled,y_train)
dtc.score(X_test_scaled, y_test)
# Out:
# 0.49466192170818507

# %% [markdown]
# **Task (5) – Evaluation: How good are your models**

# %% [markdown]
# **5.a)**

# %%
#Confusion matrix for KNeighborsClassifier
y_pred_knn = knn.predict(X_test_scaled)

from sklearn import metrics
knn_matrix = metrics.confusion_matrix(y_test, y_pred_knn)
plt.figure(dpi=80)
sns.heatmap(knn_matrix, cmap=plt.cm.Blues, annot=True, square=True, fmt='d',
       xticklabels=["High Risk","Low Risk","Moderate Risk"],
       yticklabels=["High Risk","Low Risk","Moderate Risk"]);
plt.title('Confusion matrix for KNeighborsClassifier', y=1.1)
plt.xlabel('Prediction')
plt.ylabel('Actual')
# Out:
# Text(63.53777777777783, 0.5, 'Actual')

# %%
#Confusion matrix for Gaussian Naive Bayes
y_pred_gnb = gnb.predict(X_test_scaled)

from sklearn import metrics
gnb_matrix = metrics.confusion_matrix(y_test, y_pred_gnb)
plt.figure(dpi=80)
sns.heatmap(gnb_matrix, cmap=plt.cm.Blues, annot=True, square=True, fmt='d',
       xticklabels=["High Risk","Low Risk","Moderate Risk"],
       yticklabels=["High Risk","Low Risk","Moderate Risk"]);
plt.title('Confusion matrix for Gaussian Naive Bayes', y=1.1)
plt.xlabel('Prediction')
plt.ylabel('Actual')
# Out:
# Text(63.53777777777783, 0.5, 'Actual')

# %%
#Confusion matrix for Multinomial Naive Bayes
y_pred_mnb = mnb.predict(X_test_scaled)

from sklearn import metrics
gnb_matrix = metrics.confusion_matrix(y_test, y_pred_mnb)
plt.figure(dpi=80)
sns.heatmap(gnb_matrix, cmap=plt.cm.Blues, annot=True, square=True, fmt='d',
       xticklabels=["High Risk","Low Risk","Moderate Risk"],
       yticklabels=["High Risk","Low Risk","Moderate Risk"]);
plt.title('Confusion matrix for Multinomial Naive Bayes', y=1.1)
plt.xlabel('Prediction')
plt.ylabel('Actual')
# Out:
# Text(63.53777777777783, 0.5, 'Actual')

# %%
#Confusion matrix for Bernoulli Naive Bayes
y_pred_bnb = bnb.predict(X_test_scaled)

from sklearn import metrics
gnb_matrix = metrics.confusion_matrix(y_test, y_pred_bnb)
plt.figure(dpi=80)
sns.heatmap(gnb_matrix, cmap=plt.cm.Blues, annot=True, square=True, fmt='d',
       xticklabels=["High Risk","Low Risk","Moderate Risk"],
       yticklabels=["High Risk","Low Risk","Moderate Risk"]);
plt.title('Confusion matrix for Bernoulli Naive Bayes', y=1.1)
plt.xlabel('Prediction')
plt.ylabel('Actual')
# Out:
# Text(63.53777777777783, 0.5, 'Actual')

# %%
#Confusion matrix for Decision Tree Classifier
y_pred_dtc = dtc.predict(X_test_scaled)

from sklearn import metrics
dtc_matrix = metrics.confusion_matrix(y_test, y_pred_dtc)
plt.figure(dpi=80)
sns.heatmap(dtc_matrix, cmap=plt.cm.Blues, annot=True, square=True, fmt='d',
       xticklabels=["High Risk","Low Risk","Moderate Risk"],
       yticklabels=["High Risk","Low Risk","Moderate Risk"]);
plt.title('Confusion matrix for Decision Tree Classifier', y=1.1)
plt.xlabel('Prediction')
plt.ylabel('Actual')
# Out:
# Text(63.53777777777783, 0.5, 'Actual')

# %% [markdown]
# **5.b)**

# %%
#KNN Scores
print(classification_report(y_test, y_pred_knn))

from sklearn.metrics import RocCurveDisplay
y_score = knn.predict_proba(X_test_scaled)

from sklearn.preprocessing import LabelBinarizer

label_binarizer = LabelBinarizer().fit(y_train)
y_onehot_test = label_binarizer.transform(y_test)

from sklearn.metrics import roc_curve, auc

# store the fpr, tpr, and roc_auc for all averaging strategies
fpr, tpr, roc_auc = dict(), dict(), dict()
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_onehot_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

n_classes = len(np.unique(y))
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_onehot_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr_grid = np.linspace(0.0, 1.0, 1000)

# Interpolate all ROC curves at these points
mean_tpr = np.zeros_like(fpr_grid)

for i in range(n_classes):
    mean_tpr += np.interp(fpr_grid, fpr[i], tpr[i])  # linear interpolation

# Average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = fpr_grid
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

from itertools import cycle
target_names = ['High Risk', 'Low Risk', 'Moderate Risk']

fig, ax = plt.subplots(figsize=(6, 6))

plt.plot(
    fpr["micro"],
    tpr["micro"],
    label=f"micro-average ROC curve (AUC = {roc_auc['micro']:.2f})",
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label=f"macro-average ROC curve (AUC = {roc_auc['macro']:.2f})",
    color="navy",
    linestyle=":",
    linewidth=4,
)

colors = cycle(["aqua", "darkorange", "cornflowerblue"])
for class_id, color in zip(range(n_classes), colors):
    RocCurveDisplay.from_predictions(
        y_onehot_test[:, class_id],
        y_score[:, class_id],
        name=f"ROC curve for {target_names[class_id]}",
        color=color,
        ax=ax,
    )

plt.plot([0, 1], [0, 1], "k--", label="ROC curve for chance level (AUC = 0.5)")
plt.axis("square")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Extension of Receiver Operating Characteristic\nto One-vs-Rest multiclass")
plt.legend()
plt.show()
# Out:
#                precision    recall  f1-score   support
#
#     High Risk       0.62      0.62      0.62       226
#      Low Risk       0.46      0.38      0.42        92
# Moderate Risk       0.53      0.57      0.55       244
#
#      accuracy                           0.56       562
#     macro avg       0.54      0.52      0.53       562
#  weighted avg       0.55      0.56      0.55       562

# %%
#MNB Scores
print(classification_report(y_test, y_pred_mnb))

from sklearn.metrics import RocCurveDisplay
y_score = mnb.predict_proba(X_test_scaled)

from sklearn.preprocessing import LabelBinarizer

label_binarizer = LabelBinarizer().fit(y_train)
y_onehot_test = label_binarizer.transform(y_test)

from sklearn.metrics import roc_curve, auc

# store the fpr, tpr, and roc_auc for all averaging strategies
fpr, tpr, roc_auc = dict(), dict(), dict()
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_onehot_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

n_classes = len(np.unique(y))
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_onehot_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr_grid = np.linspace(0.0, 1.0, 1000)

# Interpolate all ROC curves at these points
mean_tpr = np.zeros_like(fpr_grid)

for i in range(n_classes):
    mean_tpr += np.interp(fpr_grid, fpr[i], tpr[i])  # linear interpolation

# Average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = fpr_grid
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

from itertools import cycle
target_names = ['High Risk', 'Low Risk', 'Moderate Risk']

fig, ax = plt.subplots(figsize=(6, 6))

plt.plot(
    fpr["micro"],
    tpr["micro"],
    label=f"micro-average ROC curve (AUC = {roc_auc['micro']:.2f})",
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label=f"macro-average ROC curve (AUC = {roc_auc['macro']:.2f})",
    color="navy",
    linestyle=":",
    linewidth=4,
)

colors = cycle(["aqua", "darkorange", "cornflowerblue"])
for class_id, color in zip(range(n_classes), colors):
    RocCurveDisplay.from_predictions(
        y_onehot_test[:, class_id],
        y_score[:, class_id],
        name=f"ROC curve for {target_names[class_id]}",
        color=color,
        ax=ax,
    )

plt.plot([0, 1], [0, 1], "k--", label="ROC curve for chance level (AUC = 0.5)")
plt.axis("square")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Extension of Receiver Operating Characteristic\nto One-vs-Rest multiclass")
plt.legend()
plt.show()
# Out:
#                precision    recall  f1-score   support
#
#     High Risk       0.76      0.35      0.48       226
#      Low Risk       0.00      0.00      0.00        92
# Moderate Risk       0.49      0.93      0.64       244
#
#      accuracy                           0.54       562
#     macro avg       0.42      0.43      0.37       562
#  weighted avg       0.52      0.54      0.47       562
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#GNB Scores
print(classification_report(y_test, y_pred_gnb))

from sklearn.metrics import RocCurveDisplay
y_score = gnb.predict_proba(X_test_scaled)

from sklearn.preprocessing import LabelBinarizer

label_binarizer = LabelBinarizer().fit(y_train)
y_onehot_test = label_binarizer.transform(y_test)

from sklearn.metrics import roc_curve, auc

# store the fpr, tpr, and roc_auc for all averaging strategies
fpr, tpr, roc_auc = dict(), dict(), dict()
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_onehot_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

n_classes = len(np.unique(y))
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_onehot_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr_grid = np.linspace(0.0, 1.0, 1000)

# Interpolate all ROC curves at these points
mean_tpr = np.zeros_like(fpr_grid)

for i in range(n_classes):
    mean_tpr += np.interp(fpr_grid, fpr[i], tpr[i])  # linear interpolation

# Average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = fpr_grid
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

from itertools import cycle
target_names = ['High Risk', 'Low Risk', 'Moderate Risk']

fig, ax = plt.subplots(figsize=(6, 6))

plt.plot(
    fpr["micro"],
    tpr["micro"],
    label=f"micro-average ROC curve (AUC = {roc_auc['micro']:.2f})",
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label=f"macro-average ROC curve (AUC = {roc_auc['macro']:.2f})",
    color="navy",
    linestyle=":",
    linewidth=4,
)

colors = cycle(["aqua", "darkorange", "cornflowerblue"])
for class_id, color in zip(range(n_classes), colors):
    RocCurveDisplay.from_predictions(
        y_onehot_test[:, class_id],
        y_score[:, class_id],
        name=f"ROC curve for {target_names[class_id]}",
        color=color,
        ax=ax,
    )

plt.plot([0, 1], [0, 1], "k--", label="ROC curve for chance level (AUC = 0.5)")
plt.axis("square")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Extension of Receiver Operating Characteristic\nto One-vs-Rest multiclass")
plt.legend()
plt.show()
# Out:
#                precision    recall  f1-score   support
#
#     High Risk       0.73      0.63      0.67       226
#      Low Risk       0.39      0.54      0.46        92
# Moderate Risk       0.55      0.54      0.55       244
#
#      accuracy                           0.58       562
#     macro avg       0.56      0.57      0.56       562
#  weighted avg       0.60      0.58      0.58       562

# %%
#BNB Scores
print(classification_report(y_test, y_pred_bnb))

from sklearn.metrics import RocCurveDisplay
y_score = bnb.predict_proba(X_test_scaled)

from sklearn.preprocessing import LabelBinarizer

label_binarizer = LabelBinarizer().fit(y_train)
y_onehot_test = label_binarizer.transform(y_test)

from sklearn.metrics import roc_curve, auc

# store the fpr, tpr, and roc_auc for all averaging strategies
fpr, tpr, roc_auc = dict(), dict(), dict()
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_onehot_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

n_classes = len(np.unique(y))
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_onehot_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr_grid = np.linspace(0.0, 1.0, 1000)

# Interpolate all ROC curves at these points
mean_tpr = np.zeros_like(fpr_grid)

for i in range(n_classes):
    mean_tpr += np.interp(fpr_grid, fpr[i], tpr[i])  # linear interpolation

# Average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = fpr_grid
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

from itertools import cycle
target_names = ['High Risk', 'Low Risk', 'Moderate Risk']

fig, ax = plt.subplots(figsize=(6, 6))

plt.plot(
    fpr["micro"],
    tpr["micro"],
    label=f"micro-average ROC curve (AUC = {roc_auc['micro']:.2f})",
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label=f"macro-average ROC curve (AUC = {roc_auc['macro']:.2f})",
    color="navy",
    linestyle=":",
    linewidth=4,
)

colors = cycle(["aqua", "darkorange", "cornflowerblue"])
for class_id, color in zip(range(n_classes), colors):
    RocCurveDisplay.from_predictions(
        y_onehot_test[:, class_id],
        y_score[:, class_id],
        name=f"ROC curve for {target_names[class_id]}",
        color=color,
        ax=ax,
    )

plt.plot([0, 1], [0, 1], "k--", label="ROC curve for chance level (AUC = 0.5)")
plt.axis("square")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Extension of Receiver Operating Characteristic\nto One-vs-Rest multiclass")
plt.legend()
plt.show()
# Out:
#                precision    recall  f1-score   support
#
#     High Risk       0.41      0.82      0.55       226
#      Low Risk       0.00      0.00      0.00        92
# Moderate Risk       0.49      0.22      0.30       244
#
#      accuracy                           0.43       562
#     macro avg       0.30      0.35      0.28       562
#  weighted avg       0.38      0.43      0.35       562

# %%
#DTC Scores
print(classification_report(y_test, y_pred_dtc))

from sklearn.metrics import RocCurveDisplay
y_score = dtc.predict_proba(X_test_scaled)

from sklearn.preprocessing import LabelBinarizer

label_binarizer = LabelBinarizer().fit(y_train)
y_onehot_test = label_binarizer.transform(y_test)

from sklearn.metrics import roc_curve, auc

# store the fpr, tpr, and roc_auc for all averaging strategies
fpr, tpr, roc_auc = dict(), dict(), dict()
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_onehot_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

n_classes = len(np.unique(y))
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_onehot_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr_grid = np.linspace(0.0, 1.0, 1000)

# Interpolate all ROC curves at these points
mean_tpr = np.zeros_like(fpr_grid)

for i in range(n_classes):
    mean_tpr += np.interp(fpr_grid, fpr[i], tpr[i])  # linear interpolation

# Average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = fpr_grid
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

from itertools import cycle
target_names = ['High Risk', 'Low Risk', 'Moderate Risk']

fig, ax = plt.subplots(figsize=(6, 6))

plt.plot(
    fpr["micro"],
    tpr["micro"],
    label=f"micro-average ROC curve (AUC = {roc_auc['micro']:.2f})",
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label=f"macro-average ROC curve (AUC = {roc_auc['macro']:.2f})",
    color="navy",
    linestyle=":",
    linewidth=4,
)

colors = cycle(["aqua", "darkorange", "cornflowerblue"])
for class_id, color in zip(range(n_classes), colors):
    RocCurveDisplay.from_predictions(
        y_onehot_test[:, class_id],
        y_score[:, class_id],
        name=f"ROC curve for {target_names[class_id]}",
        color=color,
        ax=ax,
    )

plt.plot([0, 1], [0, 1], "k--", label="ROC curve for chance level (AUC = 0.5)")
plt.axis("square")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Extension of Receiver Operating Characteristic\nto One-vs-Rest multiclass")
plt.legend()
plt.show()
# Out:
#                precision    recall  f1-score   support
#
#     High Risk       0.62      0.60      0.61       226
#      Low Risk       0.28      0.35      0.31        92
# Moderate Risk       0.48      0.45      0.47       244
#
#      accuracy                           0.49       562
#     macro avg       0.46      0.47      0.46       562
#  weighted avg       0.50      0.49      0.50       562

# %% [markdown]
# **5.c)**

# %% [markdown]
# KNN

# %%
#create new a knn model
knn4 = KNeighborsClassifier()
#create a dictionary of all values we want to test for n_neighbors
k_range = list(range(1, 100))
weight_options = ['uniform', 'distance']
metric_options = ['euclidean', 'manhattan', 'minkowski']
algorithm_options = ["auto", "ball_tree", "kd_tree", "brute"]
leaf_size_range = list(range(25, 40, 5))
p_range = list(range(1, 4))

param_grid = dict(n_neighbors=k_range, weights=weight_options, metric=metric_options, algorithm=algorithm_options,
                 leaf_size=leaf_size_range,p=p_range)
#use gridsearch to test all values for n_neighbors
knn_gscv2 = GridSearchCV(knn4, param_grid, cv=10)
#fit model to data
knn_gscv2.fit(X_scaled, y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_15319/837286696.py in <module>
#      14 knn_gscv2 = GridSearchCV(knn4, param_grid, cv=10)
#      15 #fit model to data
# ---> 16 knn_gscv2.fit(X_scaled, y)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     873                 return results
#     874
# --> 875             self._run_search(evaluate_candidates)
#     876
#     877             # multimetric is determined here because in the case of a callable
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1387     def _run_search(self, evaluate_candidates):
#    1388         """Search all candidates in param_grid"""
# -> 1389         evaluate_candidates(ParameterGrid(self.param_grid))
#    1390
#    1391
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     820                     )
#     821
# --> 822                 out = parallel(
#     823                     delayed(_fit_and_score)(
#     824                         clone(base_estimator),
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1049                 self._iterating = self._original_iterator is not None
#    1050
# -> 1051             while self.dispatch_one_batch(iterator):
#    1052                 pass
#    1053
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     862                 return False
#     863             else:
# --> 864                 self._dispatch(tasks)
#     865                 return True
#     866
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     780         with self._lock:
#     781             job_idx = len(self._jobs)
# --> 782             job = self._backend.apply_async(batch, callback=cb)
#     783             # A job can complete so quickly than its callback is
#     784             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self)
#     261         # change the default number of processes to -1
#     262         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263             return [func(*args, **kwargs)
#     264                     for func, args, kwargs in self.items]
#     265
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in <listcomp>(.0)
#     261         # change the default number of processes to -1
#     262         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263             return [func(*args, **kwargs)
#     264                     for func, args, kwargs in self.items]
#     265
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     115     def __call__(self, *args, **kwargs):
#     116         with config_context(**self.config):
# --> 117             return self.function(*args, **kwargs)
#     118
#     119
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     706
#     707         fit_time = time.time() - start_time
# --> 708         test_scores = _score(estimator, X_test, y_test, scorer, error_score)
#     709         score_time = time.time() - start_time - fit_time
#     710         if return_train_score:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py in _score(estimator, X_test, y_test, scorer, error_score)
#     765             scores = scorer(estimator, X_test)
#     766         else:
# --> 767             scores = scorer(estimator, X_test, y_test)
#     768     except Exception:
#     769         if error_score == "raise":
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py in _passthrough_scorer(estimator, *args, **kwargs)
#     428 def _passthrough_scorer(estimator, *args, **kwargs):
#     429     """Function that wraps estimator.score"""
# --> 430     return estimator.score(*args, **kwargs)
#     431
#     432
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     636         from .metrics import accuracy_score
#     637
# --> 638         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     639
#     640     def _more_tags(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     250         for k, classes_k in enumerate(classes_):
#     251             if weights is None:
# --> 252                 mode, _ = _mode(_y[neigh_ind, k], axis=1)
#     253             else:
#     254                 mode, _ = weighted_mode(_y[neigh_ind, k], weights, axis=1)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py in _mode(a, axis)
#     170     if sp_version >= parse_version("1.9.0"):
#     171         return scipy.stats.mode(a, axis=axis, keepdims=True)
# --> 172     return scipy.stats.mode(a, axis=axis)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/stats.py in mode(a, axis, nan_policy)
#     446     counts = np.empty(a_view.shape[:-1], dtype=np.int_)
#     447     for ind in inds:
# --> 448         modes[ind], counts[ind] = _mode1D(a_view[ind])
#     449     newshape = list(a.shape)
#     450     newshape[axis] = 1
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/stats.py in _mode1D(a)
#     432
#     433     def _mode1D(a):
# --> 434         vals, cnts = np.unique(a, return_counts=True)
#     435         return vals[cnts.argmax()], cnts.max()
#     436
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/overrides.py in unique(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     270     ar = np.asanyarray(ar)
#     271     if axis is None:
# --> 272         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     273         return _unpack_tuple(ret)
#     274
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     333         ar.sort()
#     334         aux = ar
# --> 335     mask = np.empty(aux.shape, dtype=np.bool_)
#     336     mask[:1] = True
#     337     if aux.shape[0] > 0 and aux.dtype.kind in "cfmM" and np.isnan(aux[-1]):
#
# KeyboardInterrupt:

# %%
print('Best Score:', knn_gscv2.best_score_, 'Best Parameters:', knn_gscv2.best_params_)

# %%
# Calculating error for K values between 1 and 100
error = []

# Calculating error for K values between 1 and 100
for i in range(1, 100):
    knn = KNeighborsClassifier(n_neighbors = i, algorithm='auto', leaf_size=25, metric='manhattan',
                           p=1, weights='uniform')
    knn.fit(X_train_scaled, y_train)
    pred_i = knn.predict(X_test_scaled)
    error.append(np.mean(pred_i != y_test))
plt.figure(figsize=(12, 6))
plt.plot(range(1, 100), error, color='red', linestyle='dashed', marker='o',
         markerfacecolor='blue', markersize=10)
plt.title('Error Rate K Value')
plt.xlabel('K Value')
plt.ylabel('Mean Error')

# %%
# Create KNN classifier
knn = KNeighborsClassifier(n_neighbors = 74, algorithm='auto', leaf_size=25, metric='manhattan',
                           p=1, weights='uniform')
# Fit the classifier to the data
knn.fit(X_train_scaled,y_train)
#check accuracy of our model on the test data
knn.score(X_test_scaled, y_test)

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
#create a new KNN model
knn_cv = KNeighborsClassifier(n_neighbors = i, algorithm='auto', leaf_size=25, metric='manhattan',
                           p=1, weights='distance')
#train model with cv of 5 
cv_scores = cross_val_score(knn_cv, X_scaled, y, cv=10)
#print each cv score (accuracy) and average them
print(cv_scores)
print('cv_scores mean:{}'.format(np.mean(cv_scores)))

# %%
#Predict the response for test dataset
y_pred = knn.predict(X_test_scaled)

# import the metrics class
from sklearn import metrics
knn_matrix = metrics.confusion_matrix(y_test, y_pred)
knn_matrix

# %% [markdown]
# GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb.fit(X_train, y_train)
print("Gaussian Naive Bayes score: ",gnb.score(X_test, y_test))

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# MultinomialNB

# %%
#create a dictionary of all values we want to test
force_alpha_options = [True,False]
fit_prior_options = [True,False]

param_grid = dict(force_alpha=force_alpha_options, fit_prior=fit_prior_options)
#use gridsearch to test all values
mnb_gscv = GridSearchCV(mnb, param_grid, cv=10)
#fit model to data
mnb_gscv.fit(X_train_scaled, y_train)
print('Best Score:', mnb_gscv.best_score_, 'Best Parameters:', mnb_gscv.best_params_)

# %%
mnb = MultinomialNB(force_alpha = True, fit_prior = True)
mnb.fit(X_train_scaled, y_train)
print("Multinomial Naive Bayes score: ",mnb.score(X_test_scaled, y_test))

# %% [markdown]
# BernoulliNB

# %%
#create a dictionary of all values we want to test
force_alpha_options = [True,False]
fit_prior_options = [True,False]

param_grid = dict(force_alpha=force_alpha_options, fit_prior=fit_prior_options)
#use gridsearch to test all values
bnb_gscv = GridSearchCV(bnb, param_grid, cv=10)
#fit model to data
bnb_gscv.fit(X_train_scaled, y_train)
print('Best Score:', bnb_gscv.best_score_, 'Best Parameters:', mnb_gscv.best_params_)

# %%
# Create Bernoulli Naive Bayes classifier
bnb = BernoulliNB(force_alpha = True, fit_prior = True)
bnb.fit(X_train_scaled, y_train)
bnb.score(X_test_scaled, y_test)

# %% [markdown]
# Decision Tree

# %%
#create new a mnb model
dtc2 = DecisionTreeClassifier()
#create a dictionary of all values we want to test
criterion_options = ["gini", "entropy", "log_loss"]
splitter_options = ["best", "random"]
max_depth_range = list(range(1, 11))
max_depth_range.append(None)
min_samples_split_range = list(range(2, 6))
min_samples_leaf_range = list(range(1, 6))
max_features_options = ["auto", "sqrt", "log2",None]

param_grid = dict(criterion=criterion_options, splitter=splitter_options, max_depth=max_depth_range, 
                 min_samples_split=min_samples_split_range, min_samples_leaf=min_samples_leaf_range, 
                 max_features=max_features_options)
#use gridsearch to test all values
dtc_gscv = GridSearchCV(dtc2, param_grid, cv=10)
#fit model to data
dtc_gscv.fit(X, y)
print('Best Score:', dtc_gscv.best_score_, 'Best Parameters:', dtc_gscv.best_params_)

# %%
dtc = DecisionTreeClassifier(criterion='entropy', max_depth=4, max_features=None, min_samples_leaf=3, 
                             min_samples_split=2, splitter='best')
dtc = dtc.fit(X_train,y_train)
print("Decision Tree score: ",dtc.score(X_test, y_test))

# %%
#Predict the response for test dataset
y_pred = dtc.predict(X_test)

# import the metrics class
from sklearn import metrics
dtc_matrix = metrics.confusion_matrix(y_test, y_pred)
dtc_matrix

# %%
def make_confusion_matrix():
    plt.figure(dpi=80)
    sns.heatmap(dtc_matrix, cmap=plt.cm.Blues, annot=True, square=True, fmt='d',
           xticklabels=["High Risk","Low Risk","Moderate Risk"],
           yticklabels=["High Risk","Low Risk","Moderate Risk"]);
    plt.title('Confusion matrix for DecisionTreeClassifier', y=1.1)
    plt.xlabel('Prediction')
    plt.ylabel('Actual')
    
make_confusion_matrix()

# %%
#Check the labels
import numpy
unique, counts = numpy.unique(y_test, return_counts=True)

dict(zip(unique, counts))

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred, average='macro'))
print("Recall:",metrics.recall_score(y_test, y_pred,average='macro'))
print("F-Measure:",metrics.f1_score(y_test, y_pred,average='macro'))

# %%
y_score = dtc.predict_proba(X_test)

from sklearn.preprocessing import LabelBinarizer

label_binarizer = LabelBinarizer().fit(y_train)
y_onehot_test = label_binarizer.transform(y_test)

from sklearn.metrics import roc_curve, auc

# store the fpr, tpr, and roc_auc for all averaging strategies
fpr, tpr, roc_auc = dict(), dict(), dict()
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_onehot_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

n_classes = len(np.unique(y))
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_onehot_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr_grid = np.linspace(0.0, 1.0, 1000)

# Interpolate all ROC curves at these points
mean_tpr = np.zeros_like(fpr_grid)

for i in range(n_classes):
    mean_tpr += np.interp(fpr_grid, fpr[i], tpr[i])  # linear interpolation

# Average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = fpr_grid
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

from itertools import cycle
target_names = ['High Risk', 'Low Risk', 'Moderate Risk']

fig, ax = plt.subplots(figsize=(6, 6))

plt.plot(
    fpr["micro"],
    tpr["micro"],
    label=f"micro-average ROC curve (AUC = {roc_auc['micro']:.2f})",
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label=f"macro-average ROC curve (AUC = {roc_auc['macro']:.2f})",
    color="navy",
    linestyle=":",
    linewidth=4,
)

colors = cycle(["aqua", "darkorange", "cornflowerblue"])
for class_id, color in zip(range(n_classes), colors):
    RocCurveDisplay.from_predictions(
        y_onehot_test[:, class_id],
        y_score[:, class_id],
        name=f"ROC curve for {target_names[class_id]}",
        color=color,
        ax=ax,
    )

plt.plot([0, 1], [0, 1], "k--", label="ROC curve for chance level (AUC = 0.5)")
plt.axis("square")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Extension of Receiver Operating Characteristic\nto One-vs-Rest multiclass")
plt.legend()
plt.show()
